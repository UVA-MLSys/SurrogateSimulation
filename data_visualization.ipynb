# %% [markdown]
# # Input Data and Graphs

# %% [markdown]
# We first began by formatting and graphing the results of ETAS

# %%
# Import Libraries
import pandas as pd
import matplotlib.pyplot as plt

# Specify the CSV file path
csv_file = 'Formatted_ETAS_Output.csv'

# Read the CSV file using Pandas
df = pd.read_csv(csv_file)

# Access the data in the DataFrame
print(df.head())
# Out:
#        Date     Time         Year         X        Y  Magnitude       Z
# 0  12/31/59  03:09.0  1960.002196 -119.0502  33.9790       6.50  8.2474
# 1    1/2/60  08:49.0  1960.006125 -115.6222  33.0793       4.25  7.9322
# 2    1/2/60  10:31.0  1960.007305 -115.6323  33.1220       3.03  8.4015
# 3    1/2/60  10:32.0  1960.007320 -115.5851  33.0745       3.03  7.9678
# 4    1/2/60  11:07.0  1960.007720 -115.6256  33.0290       3.08  7.9737

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['Year'], df['Magnitude'], 'b.')
plt.xlabel('Year')
plt.ylabel('Magnitude')
plt.title('Earthquake Magnitude over Time')
plt.xticks(rotation=45)
plt.grid(True)
plt.show(block=True)

plt.hist(df['Magnitude'], bins=10)
plt.title('Magnitude Histogram')
plt.xlabel('Magnitude')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()


plt.scatter(df['X'], df['Y'], c=df['Magnitude'], cmap='viridis', s=50)  # Adjust the size (s) of the points as per your preference
plt.title('Earthquake Coordinates')
plt.xlabel('X')
plt.ylabel('Y')
cbar = plt.colorbar()
cbar.set_label('Magnitude')
plt.show()
